# %% [markdown]
# ### String Matching
#
# 정보검색, 통신시스템, 프로그래밍 시스템, 유전체학 등에 필요
#
#
# 고지식, 카프라빈, KMP, 보이어무어, 그리고 파이썬의 패턴매칭
#
# 고지식방법: O(MN)
#
# 카프라빈: 해시사용해서
#
# KMP: 이동할 위치로 O(M+N)
#
#     # <패턴에 대해 불일치 발생시 돌아갈 곳을 계산하는 전처리 함수 알고리즘>
#     # p: 패턴, M: 패턴의 길이
#     # next: 불일치가 발생하면 이동할 위치 저장
#
#     def KMP_preprocss(p,next):
#         M = len(p)
#         i = 0
#         j = -1
#         while i <M:
#             next_[i] = j
#             while j >= 0 and p[i] != p[j]:
#                 j = next_[j]
#
#         i += 1
#         j += 1
#
#     # <전처리를 통해 계산된 넥스트 리스트를 이용해 패턴을 찾는 알고리즘>
#     # t: 텍스트,  p: 패턴,  N: 텍스트의 길이, M: 패턴의 길이
#     # next: 불일치 발생시 이동 위치 저장
#
#     def KMP_Search(t,p,next_):
#         N = len(t)
#         M = len(p)
#         i = 0
#         j = 0
#         while i < N:
#             while j >= 0 and t[i] != p[j]:
#                 j=next_[j]
#             i+=1
#             j+=1
#             if j==M:
#                 return i-j
#         return -1
#
# 보이어-무어: 평균: O(N)
#
# 패턴을 뒤에서 부터 비교, 대부분 상용 SW에서 채택
#
# ex) rithm의 skip list<br>
# m h t i r<br>
# 0 1 2 3 4
#
# ### python에서 matching
#
# in 또는 find() <br>
# cf) find 보이어 무어사용
#
#     A = "abcdefg"
#     b = "cd"
#     A.find(b) # output: 2
#
# ### trie
#
# 트리 구조로
#
# 압축도 가능하다.
#
# - 접미어 트리
#
# 간선에 기릿
#
# 필요할 지 잘 몰겠다. $를 추가해서 마지막 위치에
#
# 메모리가 많이 필요하다
#
# - 접미어 배열
#
# 텍스트 인덱싱 데이터 압축 바이오인포메틱 등에 사용
#
# 메모리가 좀더 효율적
#
# ### 압축
#
# 저장 공간, 전송 시간 절약
#
# - RLE (Run Length Encoding)
#
# 동일한 값 압축
#
# - 허프만 코드
#
# 이런 거 정검때
